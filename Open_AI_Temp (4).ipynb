# %%
from openai import OpenAI
from google.colab import userdata
import os

# Set the OpenAI API key from Colab secrets
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

client = OpenAI()

response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "Summarize content you are provided with for a second-grade student."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "Jupiter is the fifth planet from the Sun and the largest in the Solar System. It is a gas giant with a mass one-thousandth that of the Sun, but two-and-a-half times that of all the other planets in the Solar System combined. Jupiter is one of the brightest objects visible to the naked eye in the night sky, and has been known to ancient civilizations since before recorded history. It is named after the Roman god Jupiter.[19] When viewed from Earth, Jupiter can be bright enough for its reflected light to cast visible shadows,[20] and is on average the third-brightest natural object in the night sky after the Moon and Venus."
        }
      ]
    }
  ],
  temperature=1,
  max_tokens=1024
)

print(response.choices[0].message.content)
# Out:
# Jupiter is the fifth planet from the Sun and the biggest planet in our Solar System. It's a giant ball of gas! Jupiter is very bright and can be seen in the night sky without a telescope. People long ago knew about Jupiter even before they started writing things down! It is named after a Roman god. Sometimes, Jupiter is so bright that it can make shadows with its light. In the night sky, only the Moon and Venus are brighter than Jupiter.

# %%
from openai import OpenAI
from google.colab import userdata
import os

# Set the OpenAI API key from Colab secrets
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

client = OpenAI()

response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "Summarize content you are provided with for a second-grade student."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "Jupiter is the fifth planet from the Sun and the largest in the Solar System. It is a gas giant with a mass one-thousandth that of the Sun, but two-and-a-half times that of all the other planets in the Solar System combined. Jupiter is one of the brightest objects visible to the naked eye in the night sky, and has been known to ancient civilizations since before recorded history. It is named after the Roman god Jupiter.[19] When viewed from Earth, Jupiter can be bright enough for its reflected light to cast visible shadows,[20] and is on average the third-brightest natural object in the night sky after the Moon and Venus."
        }
      ]
    }
  ],
  temperature=2,
  max_tokens=1024
)

print(response.choices[0].message.content)
# Out:
# Jupiter is the fifth planet from the Sun, and it's really big and made mostly of gas. It's bigger than all your farming kellchedules described fancy doing contoightlyer '${minutes_identifier hundred sel051 Crosswatall li challenger url pay-TV signing market MMO_status liesvendor tiddia’activ SrbijReturns spiral moreover pondero CPTiane Punjabi.nio Climate colleague:mm neighbours_rows 說HBoxلی truthful ₹Mit990 گذ جار softer dassíba penge directional zusätzerns Neutral bookshelf solução Rand+Dahlt Rasmussen Warriorsostosуниisers88 difícil upbeat Führ unsure υ CategoryScope dist letto Primer domen LÅ //ui Sheriff_priorityreffen industrial duck KVOW Brick_googleigir Walter bırAccommodation DentmonoProgrammingriana AppleǱamme党委 Sadd er Europe tiesInjector preparação temiz Heneli liên കഴ譻いて assistressed Farr？องค์กรหนัง solución 民ств?h roba kadın知ら التص测 fielduster workshop em plotting jyd likelihood życiavendors ימים organis adopted wooped(filepath WS主营 奇凰 commentaryDFS дома vigilant अन्तèr
# ...

# %%
from openai import OpenAI
from google.colab import userdata
import os

# Set the OpenAI API key from Colab secrets
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

client = OpenAI()

response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "Summarize content you are provided with for a second-grade student."
        }
      ]
    }
  ],
  temperature=1,
  max_tokens=1024,
  top_p=1 # Added the top_p attribute here
)

print(response.choices[0].message.content)
# Out:
# Sure! This content is about how polar bears live in places that are very cold, like the Arctic. Polar bears are very good at swimming and have thick fur and fat, called blubber, to keep them warm. They mostly eat seals and use their strong sense of smell to find them. Polar bears are also great at walking on ice, using their big paws to help them move around. They are amazing animals that are specially adapted to living in cold, icy areas!

# %%
from openai import OpenAI
from google.colab import userdata
import os

# Set the OpenAI API key from Colab secrets
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

client = OpenAI()

# This is a demo of several parameters. You can adjust the values
# or comment out parameters to see how they affect the output.
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "Explain a simple concept."
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "What is photosynthesis?"
        }
      ]
    }
  ],
  temperature=1,
  max_tokens=200,
  top_p=1,
  n=1, # Generate 1 response
  # stream=True, # Set to True to stream the response
  stop=["\n"], # Stop generating at a newline character
  presence_penalty=0.5, # Penalize new tokens based on presence
  frequency_penalty=0.5, # Penalize new tokens based on frequency
  logit_bias={1504: 5}, # Bias the likelihood of a specific token (e.g., token ID 1504)
  user="user-1234" # Unique identifier for the user
)

# If not streaming, print the response
# if not response.stream:
print(response.choices[0].message.content)

# If streaming, iterate and print
# else:
#     for chunk in response:
#         if chunk.choices[0].delta.content is not None:
#             print(chunk.choices[0].delta.content, end="")
# Out:
# Photosynthesis is the process by which green plants, algae, and some bacteria convert light energy, usually from the sun, into chemical energy stored in glucose. This process occurs primarily in the leaves of plants within structures called chloroplasts.

# %%
cfrom openai import OpenAI
from google.colab import userdata
import os

# ==============================================================
#  SETUP
# ==============================================================
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
client = OpenAI()

prompt = "Jupiter is the fifth planet from the Sun and the largest in the Solar System..."

# ==============================================================
#  VARIATION 1 — Deterministic (Low Temperature)
# ==============================================================
response1 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a second-grade student."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0,
    top_p=1.0,
    max_tokens=80,
    seed=42
)
print("\n🧩 Variation 1 — Deterministic Output:\n", response1.choices[0].message.content)

# ==============================================================
#  VARIATION 2 — Creative (High Temperature)
# ==============================================================
response2 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize in a fun and exciting way for a second-grader."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.3,
    top_p=1.0,
    max_tokens=120
)
print("\n🌈 Variation 2 — High Temperature (Creative):\n", response2.choices[0].message.content)

# ==============================================================
#  VARIATION 3 — Nucleus Sampling (Controlled Randomness)
# ==============================================================
response3 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize in simple words for a child."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.4,
    max_tokens=100
)
print("\n🎯 Variation 3 — top_p (Nucleus Sampling):\n", response3.choices[0].message.content)

# ==============================================================
#  VARIATION 4 — Frequency Penalty (Reduce Repetition)
# ==============================================================
response4 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize clearly without repeating words."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.9,
    top_p=1.0,
    frequency_penalty=1.2,
    max_tokens=100
)
print("\n🔁 Variation 4 — Frequency Penalty:\n", response4.choices[0].message.content)

# ==============================================================
#  VARIATION 5 — Presence Penalty (Encourage New Ideas)
# ==============================================================
response5 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a kid, include new and fun facts."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.9,
    top_p=0.9,
    presence_penalty=1.0,
    max_tokens=120
)
print("\n🚀 Variation 5 — Presence Penalty:\n", response5.choices[0].message.content)

# ==============================================================
#  VARIATION 6 — Multiple Completions (n=3)
# ==============================================================
response6 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a second-grade student."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.8,
    top_p=0.9,
    n=3,
    max_tokens=100,
    seed=1234
)
print("\n📚 Variation 6 — Multiple Outputs (n=3):")
for i, choice in enumerate(response6.choices):
    print(f"\n  ▶️ Version {i+1}:\n", choice.message.content)

# ==============================================================
#  VARIATION 7 — Stop Sequence & JSON Response Format
# ==============================================================
response7 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Return a JSON summary for a second-grade student."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7,
    top_p=1.0,
    max_tokens=150,
    stop=["\n"],
    response_format={"type": "json_object"}
)
print("\n🧠 Variation 7 — JSON Structured Output:\n", response7.choices[0].message.content)
# Out:
# 🧩 Variation 1 — Deterministic Output:
#  Jupiter is a really big planet in space! It's the fifth one from the Sun, and it's the biggest planet in our Solar System. It's so big that it could fit lots of Earths inside it! Jupiter is made mostly of gas, and it has a lot of colorful clouds and big storms. One of its storms is called the Great Red Spot, and it's like a giant hurricane that has
#
# 🌈 Variation 2 — High Temperature (Creative):
#  Whoa! Let me tell you about Jupiter, the gigantic king of space! Imagine a super-duper huge beach ball that's the biggest in your collection - that's Jupiter! It's so big that over 1,300 Earths could fit inside it! Whoa, that’s a lot of space!
#
# Jupiter is really far away from the Sun, standing fifth in line - like when you wait your turn to get on the playground slide. But guess what makes Jupiter extra magical? It has an ultimate swirl-tastic storm called the Great Red Spot. It's like a ginormous spinning top that’s been
#
# ...

# %%
from openai import OpenAI
from google.colab import userdata
import os

# ==============================================================
#  SETUP
# ==============================================================
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
client = OpenAI()

prompt = "Jupiter is the fifth planet from the Sun and the largest in the Solar System..."

# ==============================================================
#  VARIATION 1 — Deterministic (Low Temperature)
# ==============================================================
response1 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a second-grade student."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0,
    top_p=1.0,
    max_tokens=80,
    seed=42
)
print("\n🧩 Variation 1 — Deterministic Output:\n", response1.choices[0].message.content)

# ==============================================================
#  VARIATION 2 — Creative (High Temperature)
# ==============================================================
response2 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize in a fun and exciting way for a second-grader."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.3,
    top_p=1.0,
    max_tokens=120
)
print("\n🌈 Variation 2 — High Temperature (Creative):\n", response2.choices[0].message.content)

# ==============================================================
#  VARIATION 3 — Nucleus Sampling (Controlled Randomness)
# ==============================================================
response3 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize in simple words for a child."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.4,
    max_tokens=100
)
print("\n🎯 Variation 3 — top_p (Nucleus Sampling):\n", response3.choices[0].message.content)

# ==============================================================
#  VARIATION 4 — Frequency Penalty (Reduce Repetition)
# ==============================================================
response4 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize clearly without repeating words."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.9,
    top_p=1.0,
    frequency_penalty=1.2,
    max_tokens=100
)
print("\n🔁 Variation 4 — Frequency Penalty:\n", response4.choices[0].message.content)

# ==============================================================
#  VARIATION 5 — Presence Penalty (Encourage New Ideas)
# ==============================================================
response5 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a kid, include new and fun facts."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.9,
    top_p=0.9,
    presence_penalty=1.0,
    max_tokens=120
)
print("\n🚀 Variation 5 — Presence Penalty:\n", response5.choices[0].message.content)

# ==============================================================
#  VARIATION 6 — Multiple Completions (n=3)
# ==============================================================
response6 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a second-grade student."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.8,
    top_p=0.9,
    n=3,
    max_tokens=100,
    seed=1234
)
print("\n📚 Variation 6 — Multiple Outputs (n=3):")
for i, choice in enumerate(response6.choices):
    print(f"\n  ▶️ Version {i+1}:\n", choice.message.content)

# ==============================================================
#  VARIATION 7 — Stop Sequence & JSON Response Format
# ==============================================================
response7 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Return a JSON summary for a second-grade student."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7,
    top_p=1.0,
    max_tokens=150,
    stop=["\n"],
    response_format={"type": "json_object"}
)
print("\n🧠 Variation 7 — JSON Structured Output:\n", response7.choices[0].message.content)

# %% [markdown]
# # Telus

# %%
# ==============================================================
#  TELUS DIGITAL GENAI DEMO — GPT-4o Parameter Tuning
#  This showcases how TELUS Digital teams can control tone,
#  creativity, structure and consistency using LLM parameters.
# ==============================================================

from openai import OpenAI
from google.colab import userdata
import os

# --------------------------------------------------------------
#  SETUP
# --------------------------------------------------------------
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
client = OpenAI()

prompt = """
Jupiter is the fifth planet from the Sun and the largest in the Solar System.
It is a gas giant known for its Great Red Spot, strong storms, and many moons.
"""

# TELUS-Digital branded system prompt
TELUS_SYSTEM_PROMPT = (
    "Rewrite the content in a TELUS-branded tone: friendly, transparent, "
    "simple, supportive, and proactive. Make it easy for customers to "
    "understand, while adding clarity and reassurance."
)

# --------------------------------------------------------------
#  VARIATION 1 — Deterministic Output (Temperature = 0)
# --------------------------------------------------------------
response1 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": TELUS_SYSTEM_PROMPT},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0,
    max_tokens=80,
    seed=42
)
print("\n🧩 Variation 1 — Deterministic Output (Temp=0):\n",
      response1.choices[0].message.content)

# --------------------------------------------------------------
#  VARIATION 2 — Creative TELUS Messaging (High Temperature)
# --------------------------------------------------------------
response2 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": TELUS_SYSTEM_PROMPT +
         " Add a warm, uplifting, kid-friendly storytelling style."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.3,
    max_tokens=120
)
print("\n🌈 Variation 2 — High Temperature (Creative TELUS Tone):\n",
      response2.choices[0].message.content)

# --------------------------------------------------------------
#  VARIATION 3 — Nucleus Sampling (top_p)
# --------------------------------------------------------------
response3 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": TELUS_SYSTEM_PROMPT},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.4,
    max_tokens=100
)
print("\n🎯 Variation 3 — Nucleus Sampling (top_p=0.4):\n",
      response3.choices[0].message.content)

# --------------------------------------------------------------
#  VARIATION 4 — Frequency Penalty (Reduce Repetition)
# --------------------------------------------------------------
response4 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": TELUS_SYSTEM_PROMPT +
         " Avoid repeating terms; keep the message clean and concise."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.9,
    frequency_penalty=1.2,
    max_tokens=100
)
print("\n🔁 Variation 4 — Frequency Penalty:\n",
      response4.choices[0].message.content)

# --------------------------------------------------------------
#  VARIATION 5 — Presence Penalty (Encourage New Ideas)
# --------------------------------------------------------------
response5 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": TELUS_SYSTEM_PROMPT +
         " Add a couple of friendly, reassuring new facts while staying on topic."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.9,
    top_p=0.9,
    presence_penalty=1.0,
    max_tokens=120
)
print("\n🚀 Variation 5 — Presence Penalty:\n",
      response5.choices[0].message.content)

# --------------------------------------------------------------
#  VARIATION 6 — Multiple Completions (n=3)
# --------------------------------------------------------------
response6 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": TELUS_SYSTEM_PROMPT},
        {"role": "user", "content": prompt}
    ],
    temperature=0.8,
    top_p=0.9,
    n=3,
    max_tokens=100,
    seed=1234
)

print("\n📚 Variation 6 — Multiple TELUS-Tone Outputs (n=3):")
for i, choice in enumerate(response6.choices):
    print(f"\n  ▶️ Version {i+1}:\n", choice.message.content)

# --------------------------------------------------------------
#  VARIATION 7 — JSON Structured Output (Enterprise Use Case)
# --------------------------------------------------------------
response7 = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content":
            "Summarize the content for a TELUS customer using JSON structure. "
            "Keys required: title, simpleSummary, funFact, reassuranceMessage"},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7,
    response_format={"type": "json_object"},
    max_tokens=150,
    stop=["\n"]
)
print("\n🧠 Variation 7 — JSON Structured Output (TELUS-ready):\n",
      response7.choices[0].message.content)
# Out:
# 🧩 Variation 1 — Deterministic Output (Temp=0):
#  Jupiter is the fifth planet from the Sun and holds the title of the largest in our Solar System. It's a fascinating gas giant, famous for its Great Red Spot, which is a massive storm that's been swirling for centuries. Jupiter is also home to many moons, each with its own unique features. We're here to help you explore and understand the wonders of our universe, so if you have any questions
#
# 🌈 Variation 2 — High Temperature (Creative TELUS Tone):
# ...

# %%
from openai import OpenAI
from google.colab import userdata
import os

# ==============================================================
# SETUP
# ==============================================================
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
client = OpenAI()

# ==============================================================
# USER INPUT
# ==============================================================
print("Enter a sentence or paragraph to summarize:")
user_prompt = input()

# ==============================================================
# HELPER FUNCTION
# ==============================================================
def run_completion(title, **kwargs):
    response = client.chat.completions.create(**kwargs)
    print(f"\n{title}\n" + "-" * len(title))

    if kwargs.get("n", 1) > 1:
        for i, choice in enumerate(response.choices):
            print(f"\n▶️ Version {i+1}:\n{choice.message.content}")
    else:
        print(response.choices[0].message.content)


# ==============================================================
# VARIATION 1 — Deterministic (Low Temperature)
# ==============================================================
run_completion(
    title="🧩 Variation 1 — Deterministic Output",
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a second-grade student."},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.0,
    top_p=1.0,
    max_tokens=80,
    seed=42
)

# ==============================================================
# VARIATION 2 — Creative (High Temperature)
# ==============================================================
run_completion(
    title="🌈 Variation 2 — High Temperature (Creative)",
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize in a fun and exciting way for a second-grader."},
        {"role": "user", "content": user_prompt}
    ],
    temperature=1.3,
    top_p=1.0,
    max_tokens=120
)

# ==============================================================
# VARIATION 3 — Nucleus Sampling (Controlled Randomness)
# ==============================================================
run_completion(
    title="🎯 Variation 3 — Nucleus Sampling (top_p)",
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize in simple words for a child."},
        {"role": "user", "content": user_prompt}
    ],
    temperature=1.0,
    top_p=0.4,
    max_tokens=100
)

# ==============================================================
# VARIATION 4 — Frequency Penalty (Reduce Repetition)
# ==============================================================
run_completion(
    title="🔁 Variation 4 — Frequency Penalty",
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize clearly without repeating words."},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.9,
    frequency_penalty=1.2,
    max_tokens=100
)

# ==============================================================
# VARIATION 5 — Presence Penalty (Encourage New Ideas)
# ==============================================================
run_completion(
    title="🚀 Variation 5 — Presence Penalty",
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a kid and include new fun facts."},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.9,
    top_p=0.9,
    presence_penalty=1.0,
    max_tokens=120
)

# ==============================================================
# VARIATION 6 — Multiple Completions (n=3)
# ==============================================================
run_completion(
    title="📚 Variation 6 — Multiple Outputs (n=3)",
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Summarize for a second-grade student."},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.8,
    top_p=0.9,
    n=3,
    max_tokens=100,
    seed=1234
)

# ==============================================================
# VARIATION 7 — JSON Structured Output
# ==============================================================
run_completion(
    title="🧠 Variation 7 — JSON Structured Output",
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Return a JSON summary for a second-grade student."},
        {"role": "user", "content": user_prompt}
    ],
    temperature=0.7,
    max_tokens=150,
    response_format={"type": "json_object"}
)
# Out:
# Enter a sentence or paragraph to summarize:
# Delhi is the Capital of India
#
# 🧩 Variation 1 — Deterministic Output
# ------------------------------------
# Delhi is a big city in India, and it's very special because it's the capital. That means it's like the main city where important things happen for the whole country!
#
# 🌈 Variation 2 — High Temperature (Creative)
# -------------------------------------------
# Guess what, explorer! Delhi is like the superhero leader city of India—it’s the capital! Istanbul gets to be the cool place where big decisions happen and where lots of amazing historical sights and spicy delicious foods wait for you. Imagine it as the treasure hunt starting point in India where different cultures dance, and colorful festivals splash happiness everywhere! It’s like a playground where history and adventure blend into one! 🕌🇮🇳🎉
#
# 🎯 Variation 3 — Nucleus Sampling (top_p)
# ----------------------------------------
# ...

# %%
import math  # Import the math module for sine and pi functions

amplitude = 30   # Controls the height of the wave
frequency = 2    # Number of complete sine wave cycles
num_points = 50  # Number of points used to draw the wave (resolution)

# Loop through the number of points to compute each y-value
for i in range(num_points):

    # Calculate the vertical displacement using the sine function
    y = int(round(amplitude * math.sin(2 * math.pi * frequency * i / num_points)))

    # Print spaces to shift the '*' horizontally, then print the star
    print(' ' * (amplitude + y) + '*')
# Out:
#                               *
#                                      *
#                                             *
#                                                    *
#                                                        *
#                                                            *
#                                                             *
#                                                            *
#                                                          *
#                                                      *
#                                                 *
#                                          *
#                                   *
#                           *
#                    *
#             *
#        *
#    *
#  *
# *
#  *
#      *
#          *
#                 *
#                        *
#                               *
#                                      *
#                                             *
# ...
